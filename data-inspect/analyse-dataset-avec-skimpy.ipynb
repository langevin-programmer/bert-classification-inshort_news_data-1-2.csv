# %% [markdown]
# ### Analyse du dataset

# %%
import pandas as pd 
from skimpy import skim #  skimpy A light weight tool for creating summary statistics from dataframes

# %%
data= pd.read_csv("data/inshort_news_data-1-2.csv")

# %%
data.head(20)
# Out:
#     Unnamed: 0                                      news_headline  \
# 0            0  50-year-old problem of biology solved by Artif...
# 1            1  Microsoft Teams to stop working on Internet Ex...
# 2            2  Hope US won't erect barriers to cooperation: C...
# 3            3  Global smartphone sales in Q3 falls 5.7% to 36...
# 4            4  EU hoping Biden will clarify US position on di...
# 5            5  Parliamentary panel divided over key issues in...
# 6            6  Google, Facebook sign French govt's 'Tech for ...
# 7            7  Facebook could soon face its 1st antitrust sui...
# 8            8  Canada plans digital tax on tech majors like F...
# 9            9  Twitter's 'Audio Spaces' to include transcript...
# 10          10  US FCC Chairman Ajit Pai to step down on Janua...
# 11          11  Tokyo Stock Exchange CEO to resign over outage...
# 12          12  Bitcoin hits new high at over $19,860, surges ...
# ...

# %%
data["news_headline"][0]
# Out:
# '50-year-old problem of biology solved by Artificial Intelligence'

# %%
data["news_article"][0]
# Out:
# 'DeepMind\'s AI system \'AlphaFold\' has been recognised as a solution to "protein folding", a grand challenge in biology for over 50 years. DeepMind showed it can predict how proteins fold into 3D shapes, a complex process that is fundamental to understanding the biological machinery of life. AlphaFold can predict the shape of proteins within the width of an atom.'

# %%
data["news_category"][0]
# Out:
# 'technology'

# %%
data.isna().sum().sum()
# Out:
# np.int64(0)

# %%
skim(data) # voir les statistiques de notre dataframe
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 4817   │ │ string      │ 3     │                                                          │
# │ │ Number of columns │ 4      │ │ int64       │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# ...
